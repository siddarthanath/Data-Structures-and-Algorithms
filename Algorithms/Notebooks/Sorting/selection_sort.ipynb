# %% [markdown]
# # Selection Sort

# %% [markdown]
# This notebook will demonstrate a step-by-step implementation of Selection Sort.

# %% [markdown]
# ## Intuition (Visual)

# %% [markdown]
# Say we are looking to sort a list in ascending order:
#
# <div>
# <img src="https://www.programiz.com/sites/tutorial2program/files/Selection-sort-0.png" width="400"/>
# <br>
# <img src="https://www.programiz.com/sites/tutorial2program/files/Selection-sort-1.png" width="400"/>
# </div>
#
# **and so on...**

# %% [markdown]
# ## Intuition (Theoretical)

# %% [markdown]
# 1. Take a static pointer at the start of the list. Take a variable pointer, which starts one index after the static pointer, that goes through the list sequentially. Once this variable pointer finds a value which is less than (or greater than) the value of the static pointer, we store a temporary value and temporary index as a "temporary optimal" swap. We then check if the elements after this "temporary index" are less than (or greater than) the "temporary optimal" swap:
# - If so, we update the "temporary optimal" swap and keep continually checking this phenomenon till we reach the end of the list.
# - Else, we apply the swap.
# 2. The static pointer now moves to the next index i.e. second index and the variable pointer starts on index after the static pointer i.e. third index.
# 3. Repeat Step 1-2 until the entire list is sorted.

# %% [markdown]
# ## Code

# %%
# Library imports
from typing import List, Union

# %%
# Selection Sort Algorithm


class SelectionSort:
    def __init__(self, input_list: List[Union[float, int]], type_: str):
        """This initialises general values which will be used repeatedly in the class."""
        self.modify_list = input_list
        self.original_list = input_list.copy()
        self.type_ = None if type_ not in {">", "<"} else type_
        if self.type_ is None:
            raise ValueError(f"Incorrect intialisation for input {type_}!")

    def check_list(self):
        """Check for edge cases for lists."""
        # If values are all the same, then list is sorted
        if len(set(self.original_list)) == 1:
            return True
        # If length of list is singular, then list is sorted
        if len(self.original_list) == 1:
            return True
        # If list does not contain all integers or floats, then list cannot be sorted
        if not all(isinstance(x, (int, float)) for x in self.original_list):
            raise TypeError("Incorrect types in list!")

    def execute(self):
        """This performs selection sort."""
        # Check list compatibility
        if self.check_list():
            print("Returning original list:")
            return self.original_list
        # Set iterable pointer
        print("Initiate Selection Sort... \n")
        for i in range(len(self.modify_list)):
            print(f"- Iteration {i}: {self.modify_list} \n")
            # Set temporary index corresponding to minimum value
            min_index = i
            # Loop through from left to right (of the list) to find the index of minimum value
            for j in range(i+1, len(self.modify_list)):
                # Check if values after the current iterable pointer are greater than/less than the value at minimum index (and update)
                if eval(f"{self.modify_list[j]} {self.type_} {self.modify_list[min_index]}"):
                    min_index = j
            # If the index of the minimum value is not the same as the starting iterable pointer position, 
            if min_index != i:
                self.modify_list[i], self.modify_list[min_index] = self.modify_list[min_index], self.modify_list[i]
        print("Selection Sort complete...")

# %% [markdown]
# ## Test

# %%
# Instatiate class object
kwargs_1 = {"input_list": [23, 79, 92, 13, 7], "type_": ">"}
ss_alg_1 = SelectionSort(**kwargs_1)
# Perform selection sort
ss_alg_1.execute()
# Out:
# Initiate Selection Sort...
#
# - Iteration 0: [23, 79, 92, 13, 7]
#
# - Iteration 1: [7, 79, 92, 13, 23]
#
# - Iteration 2: [7, 13, 92, 79, 23]
#
# - Iteration 3: [7, 13, 23, 79, 92]
#
# - Iteration 4: [7, 13, 23, 79, 92]
#
# Selection Sort complete...

# %%
# Instatiate class object
kwargs_2 = {"input_list": [23, 79, 92, 13, 7], "type_": "<"}
ss_alg_2 = SelectionSort(**kwargs_2)
# Perform selection sort
ss_alg_2.execute()
# Out:
# Initiate Selection Sort...
#
# - Iteration 0: [23, 79, 92, 13, 7]
#
# - Iteration 1: [92, 79, 23, 13, 7]
#
# - Iteration 2: [92, 79, 23, 13, 7]
#
# - Iteration 3: [92, 79, 23, 13, 7]
#
# - Iteration 4: [92, 79, 23, 13, 7]
#
# Selection Sort complete...

# %%
# Instatiate class object
kwargs_3 = {"input_list": [25], "type_": ">"}
ss_alg_3 = SelectionSort(**kwargs_3)
# Perform selection sort
ss_alg_3.execute()
# Out:
# Returning original list:
# [25]

# %%
# Instatiate class object
kwargs_4 = {"input_list": [25, 25, 25], "type_": ">"}
ss_alg_4 = SelectionSort(**kwargs_4)
# Perform selection sort
ss_alg_4.execute()
# Out:
# Returning original list:
# [25, 25, 25]

# %%
# Instatiate class object
kwargs_5 = {"input_list": [25, "hi", 3.5], "type_": ">"}
ss_alg_5 = SelectionSort(**kwargs_5)
# Perform selection sort
ss_alg_5.execute()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 5
#       3 ss_alg_5 = SelectionSort(**kwargs_5)
#       4 # Perform selection sort
# ----> 5 ss_alg_5.execute()
#
# Cell In[54], line 28, in SelectionSort.execute(self)
#      26 """This performs selection sort."""
#      27 # Check list compatibility
# ---> 28 if self.check_list():
#      29     print("Returning original list:")
#      30     return self.original_list
#
# Cell In[54], line 23, in SelectionSort.check_list(self)
#      21 # If list does not contain all integers or floats, then list cannot be sorted
#      22 if not all(isinstance(x, (int, float)) for x in self.original_list):
# ---> 23     raise TypeError("Incorrect types in list!")
#
# TypeError: Incorrect types in list!

# %% [markdown]
# ## Final Remarks

# %% [markdown]
# Thank you for reading this notebook. Note that there exists other implementations of selection sort (which I would advise you to take a look at to see any differences of similarities with this version).
# If there are any mistakes or things that need more clarity, feel free to respond and I will be happy to reply 😊.
#
# © *PolyNath 2023*
