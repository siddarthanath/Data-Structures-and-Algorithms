# %% [markdown]
# # Quick Sort

# %% [markdown]
# This notebook will demonstrate a step-by-step implementation of Quick Sort.

# %% [markdown]
# ## Intuition (Visual)

# %% [markdown]
# Say we are looking to sort a list in ascending order:
#
# <div>
# <img src="https://i0.wp.com/blog.shahadmahmud.com/wp-content/uploads/2020/04/quicksort-1-1.png?w=804&ssl=1" width="500"/>
# <br>
# <img src="https://i0.wp.com/blog.shahadmahmud.com/wp-content/uploads/2020/04/qs1-1.gif?resize=765%2C255&ssl=1" width="500"/>
# <br>
# <img src="https://i0.wp.com/blog.shahadmahmud.com/wp-content/uploads/2020/04/qs2.gif?resize=781%2C302&ssl=1" width="500"/>
# <br>
# <img src="https://i0.wp.com/blog.shahadmahmud.com/wp-content/uploads/2020/04/quicksort-19.png?w=882&ssl=1" width="500"/>
# <br>
# <img src="https://i0.wp.com/blog.shahadmahmud.com/wp-content/uploads/2020/04/qs3.gif?resize=667%2C419&ssl=1" width="500"/>
# </div>

# %% [markdown]
# ## Intuition (Theoretical)

# %% [markdown]
# ## Code

# %%
# Library imports
from typing import List, Union

# %%
# Quick Sort Algorithm

# %% [markdown]
# ## Test

# %%
# Ascending Ordered List
input_list = [23, 79, 92, 13, 7]

# %% [markdown]
# ## Final Remarks

# %% [markdown]
# Thank you for reading this notebook. Note that there exists other implementations of selection sort (which I would advise you to take a look at to see any differences of similarities with this version).
# If there are any mistakes or things that need more clarity, feel free to respond and I will be happy to reply 😊.
#
# © *PolyNath 2023*
